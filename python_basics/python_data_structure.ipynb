# %% [markdown]
# # Data Structure in python

# %% [markdown]
# #### Data structure in python are used to store the data in structure format so that we can access the data along with we can perform all the crud operation with these data structures that we can perform in the case of db as well like crud operatiorn create read update and delete operations

# %% [markdown]
# ## Types fo data structures are in the python
# 1. List
# 2. Tuple
# 3. Set
# 4. Dictionary

# %% [markdown]
# ## the different type of data structure are differ on this basis in which  specific format we want to store the data
