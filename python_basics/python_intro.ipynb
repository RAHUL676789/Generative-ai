# %% [markdown]
# # what is python langues

# %% [markdown]
# ## python is a type of programming language that used to communicate with teh conputer or technologies

# %% [markdown]
# # what is syntax in programming langueages

# %% [markdown]
# ## syntax are nothing but the set of rules that make communication with computer with legally

# %% [markdown]
# # python syntax rule

# %% [markdown]
# ## python is a case sensitive language

# %%
name = "rahul"
Name = "rahul"
name == Name
# Out:
# True

# %%
name="rahul"
Name = "Rahul"
name == Name
# Out:
# False

# %% [markdown]
# # indentation in python

# %% [markdown]
# ## so in other programming language we , use {} to grouping the statement but in the python we use indentation for grouping the code

# %%
age = int(input("enter your age"))
if age > 18 :
    print("youre eligigble for voting");
# Out:
# youre eligigble for voting

# %%
age = int(input("enter you agae"))
if age > 18 :
print("you are eligible for votin")
# Out:
#   Cell In[8], line 3
#     print("you are eligible for votin")
#     ^
# IndentationError: expected an indented block after 'if' statement on line 2

# %% [markdown]
# # continoutation

# %% [markdown]
# ## continoutation is using the / for continoue the same code for the next line

# %%
1+2+3+\
 +6
# Out:
# 12

# %% [markdown]
# # multiple statements

# %%
a=6 ; b=8 ; c=99; d=19590

# %%
a = 6 b=99
# Out:
#   Cell In[11], line 1
#     a = 6 b=99
#           ^
# SyntaxError: invalid syntax
