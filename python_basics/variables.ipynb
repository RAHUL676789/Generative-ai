# %% [markdown]
# # Variables

# %% [markdown]
# # operators are helping in to applyin operatinon on the given operands

# %% [markdown]
# # types of the operators

# %% [markdown]
# ## these are the main types of the operators
# addition (+)
# substract (-)
# multiplicat (*)
# division (/)
# floor (//)
# modulu (%)
# exponent (**)

# %%
a = int(input("enter the first value"))
b = int (input ("enter the second value"))
operation = input("enter the operation * / + -")
print(operation)

if operation == "*":
 print(a * b)

if operation == "+":
  print(a + b)
  
if operation == "/":
  print(a / b)
# Out:
# +
# 11
